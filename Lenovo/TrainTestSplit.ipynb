# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("A:\\Machine Learning\\BMWcarprices.csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(df.Mileage,df['Sell Price($)'])
plt.xlabel("Mileage(KM)")
plt.ylabel("Sell Price($)")
# Out:
# Text(0, 0.5, 'Sell Price($)')

# %%
plt.scatter(df.Mileage,df['Age(yrs)'],color='red')
plt.xlabel("Mileage(KM)")
plt.ylabel("Age(yrs)")
# Out:
# Text(0, 0.5, 'Age(yrs)')

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 16

# %%
#train sample will be changed on each trigger
X_train
# Out:
#     Mileage  Age(yrs)
# 4     46000         4
# 2     57000         5
# 6     52000         5
# 17    69000         5
# 15    25400         3
# 10    83000         7
# 18    87600         8
# 12    59000         5
# 19    52000         5
# 8     91000         8
# 5     59000         5
# 16    28000         2
# 7     72000         6
# 11    79000         7
# 1     35000         3
# 9     67000         6

# %%
#To fixed the train sample
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([21709.56675426, 38601.84424007, 24838.94703626, 16741.82476645])

# %%
y_test
# Out:
# 0     18000
# 3     40000
# 13    27500
# 14    19400
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test,y_test)
# Out:
# 0.9022837349168499
